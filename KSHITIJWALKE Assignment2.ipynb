# %%
# Assignment No: 2
# Name: KSHITIJ NANDKUMAR WALKE
# Roll No: 37068
# Batch: D
# Title: Data Cleaning and Model Building
# Problem Statement: Perform data cleaning, integration, transformation,error correction and model building on Air Quality and Heart Disease datasets

# %%
import pandas as pd

heart = pd.read_csv("heart.csv")
air = pd.read_csv("AirQuality.csv")

heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
# Check missing values
heart.isnull().sum()

# Fill missing values
heart.fillna(heart.mean(), inplace=True)

# Remove duplicates
heart.drop_duplicates(inplace=True)

heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
data = pd.concat([heart, air], axis=0)
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1  53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2  70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3  61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4  62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target  \
# 0    2.0  2.0   3.0     0.0
# 1    0.0  0.0   3.0     0.0
# 2    0.0  0.0   3.0     0.0
# 3    2.0  1.0   3.0     0.0
# 4    1.0  3.0   2.0     0.0
#
#   Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
data = pd.concat([heart, air], axis=0)
data.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1  53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2  70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3  61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4  62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target  \
# 0    2.0  2.0   3.0     0.0
# 1    0.0  0.0   3.0     0.0
# 2    0.0  0.0   3.0     0.0
# 3    2.0  1.0   3.0     0.0
# 4    1.0  3.0   2.0     0.0
#
#   Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
# Normalize numeric columns
numeric = heart.select_dtypes(include='number')

normalized = (numeric - numeric.mean()) / numeric.std()
normalized.head()
# Out:
#         age       sex        cp  trestbps      chol       fbs   restecg  \
# 0 -0.267522  0.681525 -0.933658 -0.375932 -0.666622 -0.417753  0.900163
# 1 -0.157000  0.681525 -0.933658  0.478117 -0.840523  2.385833 -1.000880
# 2  1.721875  0.681525 -0.933658  0.762800 -1.400872 -0.417753  0.900163
# 3  0.727176  0.681525 -0.933658  0.933609 -0.840523 -0.417753  0.900163
# 4  0.837698 -1.462439 -0.933658  0.364243  0.917813  2.385833  0.900163
#
#     thalach     exang   oldpeak     slope        ca      thal    target
# 0  0.804700 -0.697187 -0.037063  0.977891  1.272867  1.118111 -1.088334
# 1  0.237102  1.429586  1.771019 -2.267418 -0.713727  1.118111 -1.088334
# 2 -1.072740  1.429586  1.340523 -2.267418 -0.713727  1.118111 -1.088334
# 3  0.499070 -0.697187 -0.898054  0.977891  0.279570  1.118111 -1.088334
# 4 -1.902307 -0.697187  0.737829 -0.644764  2.266164 -0.513143 -1.088334

# %%
# Remove remaining null values
heart.dropna(inplace=True)

heart.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = heart.drop('target', axis=1)
y = heart['target']

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = LogisticRegression()
model.fit(X_train, y_train)

print("Accuracy:", model.score(X_test, y_test))
# Out:
# /lib/python3.13/site-packages/sklearn/linear_model/_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy: 0.7631578947368421
